# %%
from kafka import KafkaConsumer
import json

# %%
c = KafkaConsumer('movielens_ratings' , bootstrap_servers=['localhost:9092'])

# %%
def process_msg(msg):
    print(msg.offset)
    dico = dict(json.loads(msg.value))
    print(dico)

# %%
for msg in c:
    process_msg(msg)
# Out:
# 148
# {'userId': 291, 'movieId': 720, 'rating': 4.0, 'timestamp': 1745999126}
# 149
# {'userId': 813, 'movieId': 826, 'rating': 4.9, 'timestamp': 1745999130}
# 150
# {'userId': 444, 'movieId': 684, 'rating': 2.2, 'timestamp': 1745999136}
# 151
# {'userId': 211, 'movieId': 278, 'rating': 3.7, 'timestamp': 1745999140}
# 152
# {'userId': 1, 'movieId': 454, 'rating': 4.2, 'timestamp': 1745999144}
# 153
# {'userId': 170, 'movieId': 463, 'rating': 2.8, 'timestamp': 1745999146}
# 154
# {'userId': 709, 'movieId': 75, 'rating': 2.7, 'timestamp': 1745999148}
# 155
# {'userId': 173, 'movieId': 890, 'rating': 2.3, 'timestamp': 1745999150}
# 156
# {'userId': 617, 'movieId': 936, 'rating': 3.2, 'timestamp': 1745999153}
# 157
# {'userId': 47, 'movieId': 534, 'rating': 2.4, 'timestamp': 1745999155}
# 158
# {'userId': 185, 'movieId': 687, 'rating': 4.3, 'timestamp': 1745999158}
# 159
# {'userId': 273, 'movieId': 167, 'rating': 3.3, 'timestamp': 1745999160}
# 160
# {'userId': 230, 'movieId': 52, 'rating': 4.0, 'timestamp': 1745999163}
# 161
# {'userId': 338, 'movieId': 921, 'rating': 4.5, 'timestamp': 1745999169}
# 162
# {'userId': 729, 'movieId': 344, 'rating': 4.4, 'timestamp': 1745999171}
# 163
# {'userId': 192, 'movieId': 93, 'rating': 1.6, 'timestamp': 1745999176}
# 164
# {'userId': 978, 'movieId': 239, 'rating': 4.2, 'timestamp': 1745999178}
# 165
# {'userId': 135, 'movieId': 996, 'rating': 4.4, 'timestamp': 1745999182}
# 166
# {'userId': 708, 'movieId': 511, 'rating': 2.7, 'timestamp': 1745999185}
# 167
# {'userId': 351, 'movieId': 155, 'rating': 4.1, 'timestamp': 1745999190}
# 168
# {'userId': 77, 'movieId': 200, 'rating': 0.6, 'timestamp': 1745999194}
# 169
# {'userId': 465, 'movieId': 254, 'rating': 3.2, 'timestamp': 1745999197}
# 170
# {'userId': 829, 'movieId': 721, 'rating': 2.2, 'timestamp': 1745999203}
# 171
# {'userId': 128, 'movieId': 870, 'rating': 3.3, 'timestamp': 1745999207}
# 172
# {'userId': 755, 'movieId': 964, 'rating': 4.8, 'timestamp': 1745999211}
# 173
# {'userId': 333, 'movieId': 412, 'rating': 1.7, 'timestamp': 1745999216}
# 174
# {'userId': 515, 'movieId': 651, 'rating': 0.9, 'timestamp': 1745999218}
# 175
# {'userId': 64, 'movieId': 731, 'rating': 2.6, 'timestamp': 1745999221}
# 176
# {'userId': 622, 'movieId': 624, 'rating': 2.5, 'timestamp': 1745999225}
# 177
# {'userId': 384, 'movieId': 642, 'rating': 2.0, 'timestamp': 1745999228}
# 178
# {'userId': 194, 'movieId': 795, 'rating': 4.2, 'timestamp': 1745999235}
# 179
# {'userId': 938, 'movieId': 479, 'rating': 3.8, 'timestamp': 1745999238}
# 180
# {'userId': 323, 'movieId': 225, 'rating': 4.4, 'timestamp': 1745999242}
# 181
# {'userId': 773, 'movieId': 215, 'rating': 0.6, 'timestamp': 1745999245}
# 182
# {'userId': 640, 'movieId': 760, 'rating': 0.6, 'timestamp': 1745999248}
# 183
# {'userId': 889, 'movieId': 72, 'rating': 2.4, 'timestamp': 1745999252}
# 184
# {'userId': 744, 'movieId': 103, 'rating': 4.0, 'timestamp': 1745999255}
# 185
# {'userId': 260, 'movieId': 391, 'rating': 3.5, 'timestamp': 1745999259}
# 186
# {'userId': 266, 'movieId': 423, 'rating': 1.0, 'timestamp': 1745999263}
# 187
# {'userId': 156, 'movieId': 236, 'rating': 3.5, 'timestamp': 1745999270}
# 188
# {'userId': 864, 'movieId': 667, 'rating': 2.7, 'timestamp': 1745999275}
# 189
# {'userId': 179, 'movieId': 514, 'rating': 1.3, 'timestamp': 1745999280}
# 190
# {'userId': 806, 'movieId': 490, 'rating': 3.2, 'timestamp': 1745999283}
# 191
# {'userId': 145, 'movieId': 250, 'rating': 3.3, 'timestamp': 1745999288}
# 192
# {'userId': 204, 'movieId': 857, 'rating': 4.7, 'timestamp': 1745999292}
# 193
# {'userId': 65, 'movieId': 258, 'rating': 1.4, 'timestamp': 1745999296}
# 194
# {'userId': 955, 'movieId': 215, 'rating': 1.0, 'timestamp': 1745999302}
# 195
# {'userId': 139, 'movieId': 953, 'rating': 3.3, 'timestamp': 1745999305}
# 196
# {'userId': 933, 'movieId': 951, 'rating': 1.1, 'timestamp': 1745999307}
# 197
# {'userId': 837, 'movieId': 374, 'rating': 3.4, 'timestamp': 1745999310}
# 198
# {'userId': 898, 'movieId': 741, 'rating': 1.6, 'timestamp': 1745999312}
# 199
# {'userId': 332, 'movieId': 655, 'rating': 3.3, 'timestamp': 1745999316}
# 200
# {'userId': 509, 'movieId': 872, 'rating': 2.3, 'timestamp': 1745999320}
# 201
# {'userId': 493, 'movieId': 510, 'rating': 1.0, 'timestamp': 1745999325}
# 202
# {'userId': 550, 'movieId': 380, 'rating': 0.8, 'timestamp': 1745999327}
# 203
# {'userId': 759, 'movieId': 508, 'rating': 0.9, 'timestamp': 1745999334}
# 204
# {'userId': 184, 'movieId': 658, 'rating': 1.0, 'timestamp': 1745999337}
# 205
# {'userId': 820, 'movieId': 489, 'rating': 2.2, 'timestamp': 1745999342}
# 206
# {'userId': 402, 'movieId': 990, 'rating': 3.2, 'timestamp': 1745999344}
# 207
# {'userId': 230, 'movieId': 824, 'rating': 3.3, 'timestamp': 1745999347}
# 208
# {'userId': 41, 'movieId': 136, 'rating': 4.1, 'timestamp': 1745999352}
# 209
# {'userId': 672, 'movieId': 496, 'rating': 3.0, 'timestamp': 1745999357}
# 210
# {'userId': 129, 'movieId': 465, 'rating': 1.5, 'timestamp': 1745999359}
# 211
# {'userId': 79, 'movieId': 974, 'rating': 4.9, 'timestamp': 1745999365}
# 212
# {'userId': 393, 'movieId': 129, 'rating': 0.8, 'timestamp': 1745999367}
# 213
# {'userId': 600, 'movieId': 256, 'rating': 3.9, 'timestamp': 1745999369}
# 214
# {'userId': 179, 'movieId': 122, 'rating': 2.4, 'timestamp': 1745999374}
# 215
# {'userId': 802, 'movieId': 97, 'rating': 3.3, 'timestamp': 1745999377}
# 216
# {'userId': 216, 'movieId': 386, 'rating': 4.9, 'timestamp': 1745999381}
# 217
# {'userId': 553, 'movieId': 958, 'rating': 1.7, 'timestamp': 1745999385}
# 218
# {'userId': 575, 'movieId': 96, 'rating': 1.2, 'timestamp': 1745999389}
# 219
# {'userId': 979, 'movieId': 560, 'rating': 1.6, 'timestamp': 1745999392}
# 220
# {'userId': 778, 'movieId': 763, 'rating': 2.2, 'timestamp': 1745999399}
# 221
# {'userId': 585, 'movieId': 564, 'rating': 3.1, 'timestamp': 1745999403}
# 222
# {'userId': 586, 'movieId': 806, 'rating': 4.2, 'timestamp': 1745999406}
# 223
# {'userId': 496, 'movieId': 380, 'rating': 4.1, 'timestamp': 1745999409}
# 224
# {'userId': 406, 'movieId': 624, 'rating': 3.6, 'timestamp': 1745999414}
# 225
# {'userId': 188, 'movieId': 0, 'rating': 4.8, 'timestamp': 1745999418}
# 226
# {'userId': 380, 'movieId': 619, 'rating': 0.9, 'timestamp': 1745999422}
# 227
# {'userId': 469, 'movieId': 934, 'rating': 2.5, 'timestamp': 1745999427}
# 228
# {'userId': 112, 'movieId': 963, 'rating': 4.3, 'timestamp': 1745999433}
# 229
# {'userId': 875, 'movieId': 980, 'rating': 2.2, 'timestamp': 1745999437}
# 230
# {'userId': 301, 'movieId': 405, 'rating': 2.8, 'timestamp': 1745999440}
# 231
# {'userId': 992, 'movieId': 806, 'rating': 2.2, 'timestamp': 1745999445}
# 232
# {'userId': 451, 'movieId': 733, 'rating': 2.4, 'timestamp': 1745999448}
# 233
# {'userId': 504, 'movieId': 187, 'rating': 4.7, 'timestamp': 1745999452}
# 234
# {'userId': 735, 'movieId': 945, 'rating': 1.5, 'timestamp': 1745999454}
# 235
# {'userId': 324, 'movieId': 210, 'rating': 4.2, 'timestamp': 1745999457}
# 236
# {'userId': 778, 'movieId': 546, 'rating': 1.0, 'timestamp': 1745999463}
# 237
# {'userId': 854, 'movieId': 526, 'rating': 1.0, 'timestamp': 1745999466}
# 238
# {'userId': 117, 'movieId': 498, 'rating': 2.6, 'timestamp': 1745999470}
# 239
# {'userId': 202, 'movieId': 727, 'rating': 2.3, 'timestamp': 1745999474}
# 240
# {'userId': 489, 'movieId': 163, 'rating': 3.0, 'timestamp': 1745999477}
# 241
# {'userId': 788, 'movieId': 15, 'rating': 3.0, 'timestamp': 1745999480}
# 242
# {'userId': 577, 'movieId': 511, 'rating': 3.4, 'timestamp': 1745999484}
# 243
# {'userId': 557, 'movieId': 519, 'rating': 3.1, 'timestamp': 1745999486}
# 244
# {'userId': 194, 'movieId': 181, 'rating': 3.4, 'timestamp': 1745999490}
# 245
# {'userId': 935, 'movieId': 631, 'rating': 2.6, 'timestamp': 1745999492}
# 246
# {'userId': 355, 'movieId': 643, 'rating': 3.9, 'timestamp': 1745999497}
# 247
# {'userId': 509, 'movieId': 87, 'rating': 4.0, 'timestamp': 1745999501}
# 248
# {'userId': 991, 'movieId': 783, 'rating': 2.8, 'timestamp': 1745999503}
# 249
# {'userId': 174, 'movieId': 886, 'rating': 3.4, 'timestamp': 1745999505}
# 250
# {'userId': 383, 'movieId': 766, 'rating': 3.4, 'timestamp': 1745999508}
# 251
# {'userId': 76, 'movieId': 389, 'rating': 2.8, 'timestamp': 1745999513}
# 252
# {'userId': 683, 'movieId': 977, 'rating': 4.0, 'timestamp': 1745999515}
# 253
# {'userId': 547, 'movieId': 725, 'rating': 3.3, 'timestamp': 1745999519}
# 254
# {'userId': 975, 'movieId': 123, 'rating': 4.4, 'timestamp': 1745999523}
# 255
# {'userId': 783, 'movieId': 988, 'rating': 1.3, 'timestamp': 1745999528}
# 256
# {'userId': 672, 'movieId': 567, 'rating': 0.7, 'timestamp': 1745999533}
# 257
# {'userId': 288, 'movieId': 746, 'rating': 3.3, 'timestamp': 1745999536}
# 258
# {'userId': 6, 'movieId': 694, 'rating': 1.2, 'timestamp': 1745999539}
# 259
# {'userId': 421, 'movieId': 763, 'rating': 3.9, 'timestamp': 1745999544}
# 260
# {'userId': 738, 'movieId': 510, 'rating': 3.2, 'timestamp': 1745999547}
# 261
# {'userId': 229, 'movieId': 312, 'rating': 3.4, 'timestamp': 1745999551}
# 262
# {'userId': 494, 'movieId': 15, 'rating': 1.9, 'timestamp': 1745999554}
# 263
# {'userId': 549, 'movieId': 126, 'rating': 0.8, 'timestamp': 1745999557}
# 264
# {'userId': 417, 'movieId': 130, 'rating': 3.9, 'timestamp': 1745999563}
# 265
# {'userId': 262, 'movieId': 317, 'rating': 1.6, 'timestamp': 1745999567}
# 266
# {'userId': 307, 'movieId': 787, 'rating': 3.4, 'timestamp': 1745999571}
# 267
# {'userId': 173, 'movieId': 246, 'rating': 0.7, 'timestamp': 1745999575}
# 268
# {'userId': 681, 'movieId': 63, 'rating': 1.4, 'timestamp': 1745999579}
# 269
# {'userId': 551, 'movieId': 995, 'rating': 1.8, 'timestamp': 1745999582}
# 270
# {'userId': 710, 'movieId': 353, 'rating': 2.6, 'timestamp': 1745999585}
# 271
# {'userId': 988, 'movieId': 752, 'rating': 3.2, 'timestamp': 1745999587}
# 272
# {'userId': 351, 'movieId': 953, 'rating': 1.6, 'timestamp': 1745999595}
# 273
# {'userId': 699, 'movieId': 773, 'rating': 1.2, 'timestamp': 1745999599}
# 274
# {'userId': 821, 'movieId': 894, 'rating': 0.9, 'timestamp': 1745999601}
# 275
# {'userId': 8, 'movieId': 615, 'rating': 4.7, 'timestamp': 1745999605}
# 276
# {'userId': 332, 'movieId': 732, 'rating': 4.4, 'timestamp': 1745999607}
# 277
# {'userId': 598, 'movieId': 888, 'rating': 1.0, 'timestamp': 1745999611}
# 278
# {'userId': 911, 'movieId': 98, 'rating': 2.6, 'timestamp': 1745999615}
# 279
# {'userId': 383, 'movieId': 211, 'rating': 1.8, 'timestamp': 1745999619}
# 280
# {'userId': 552, 'movieId': 77, 'rating': 2.7, 'timestamp': 1745999622}
# 281
# {'userId': 541, 'movieId': 959, 'rating': 3.7, 'timestamp': 1745999629}
# 282
# {'userId': 319, 'movieId': 590, 'rating': 4.6, 'timestamp': 1745999632}
# 283
# {'userId': 741, 'movieId': 490, 'rating': 3.6, 'timestamp': 1745999636}
# 284
# {'userId': 224, 'movieId': 100, 'rating': 3.3, 'timestamp': 1745999639}
# 285
# {'userId': 507, 'movieId': 791, 'rating': 4.2, 'timestamp': 1745999641}
# 286
# {'userId': 194, 'movieId': 358, 'rating': 0.8, 'timestamp': 1745999645}
# 287
# {'userId': 288, 'movieId': 497, 'rating': 2.9, 'timestamp': 1745999648}
# 288
# {'userId': 85, 'movieId': 300, 'rating': 3.5, 'timestamp': 1745999652}
# 289
# {'userId': 274, 'movieId': 145, 'rating': 4.0, 'timestamp': 1745999659}
# 290
# {'userId': 973, 'movieId': 923, 'rating': 1.3, 'timestamp': 1745999663}
# 291
# {'userId': 954, 'movieId': 386, 'rating': 1.0, 'timestamp': 1745999665}
# 292
# {'userId': 229, 'movieId': 544, 'rating': 2.3, 'timestamp': 1745999668}
# 293
# {'userId': 254, 'movieId': 81, 'rating': 4.6, 'timestamp': 1745999672}
# 294
# {'userId': 988, 'movieId': 810, 'rating': 3.0, 'timestamp': 1745999676}
# 295
# {'userId': 514, 'movieId': 145, 'rating': 3.8, 'timestamp': 1745999681}
# 296
# {'userId': 288, 'movieId': 314, 'rating': 1.0, 'timestamp': 1745999683}
# 297
# {'userId': 126, 'movieId': 830, 'rating': 2.6, 'timestamp': 1745999685}
# 298
# {'userId': 557, 'movieId': 31, 'rating': 3.7, 'timestamp': 1745999688}
# 299
# {'userId': 717, 'movieId': 576, 'rating': 0.6, 'timestamp': 1745999695}
# 300
# {'userId': 358, 'movieId': 799, 'rating': 4.0, 'timestamp': 1745999698}
# 301
# {'userId': 966, 'movieId': 435, 'rating': 3.7, 'timestamp': 1745999701}
# 302
# {'userId': 19, 'movieId': 55, 'rating': 4.5, 'timestamp': 1745999704}
# 303
# {'userId': 142, 'movieId': 79, 'rating': 4.5, 'timestamp': 1745999708}
# 304
# {'userId': 1, 'movieId': 257, 'rating': 0.8, 'timestamp': 1745999710}
# 305
# {'userId': 292, 'movieId': 985, 'rating': 5.0, 'timestamp': 1745999714}
# 306
# {'userId': 366, 'movieId': 526, 'rating': 3.7, 'timestamp': 1745999719}
# 307
# {'userId': 291, 'movieId': 333, 'rating': 2.2, 'timestamp': 1745999726}
# 308
# {'userId': 893, 'movieId': 829, 'rating': 1.1, 'timestamp': 1745999729}
# 309
# {'userId': 112, 'movieId': 151, 'rating': 3.5, 'timestamp': 1745999731}
# 310
# {'userId': 773, 'movieId': 986, 'rating': 1.1, 'timestamp': 1745999735}
# 311
# {'userId': 274, 'movieId': 497, 'rating': 3.5, 'timestamp': 1745999737}
# 312
# {'userId': 924, 'movieId': 713, 'rating': 4.7, 'timestamp': 1745999742}
# 313
# {'userId': 382, 'movieId': 347, 'rating': 3.3, 'timestamp': 1745999745}
# 314
# {'userId': 696, 'movieId': 124, 'rating': 1.6, 'timestamp': 1745999748}
# 315
# {'userId': 8, 'movieId': 253, 'rating': 0.9, 'timestamp': 1745999750}
# 316
# {'userId': 1, 'movieId': 919, 'rating': 2.8, 'timestamp': 1745999758}
# 317
# {'userId': 763, 'movieId': 960, 'rating': 3.9, 'timestamp': 1745999761}
# 318
# {'userId': 591, 'movieId': 985, 'rating': 3.7, 'timestamp': 1745999763}
# 319
# {'userId': 838, 'movieId': 82, 'rating': 4.5, 'timestamp': 1745999766}
# 320
# {'userId': 38, 'movieId': 514, 'rating': 1.9, 'timestamp': 1745999769}
# 321
# {'userId': 804, 'movieId': 861, 'rating': 1.2, 'timestamp': 1745999772}
# 322
# {'userId': 664, 'movieId': 23, 'rating': 4.2, 'timestamp': 1745999775}
# 323
# {'userId': 72, 'movieId': 214, 'rating': 2.8, 'timestamp': 1745999779}
# 324
# {'userId': 54, 'movieId': 70, 'rating': 1.5, 'timestamp': 1745999784}
# 325
# {'userId': 861, 'movieId': 427, 'rating': 4.1, 'timestamp': 1745999786}
# 326
# {'userId': 268, 'movieId': 177, 'rating': 3.2, 'timestamp': 1745999793}
# 327
# {'userId': 281, 'movieId': 964, 'rating': 3.5, 'timestamp': 1745999796}
# 328
# {'userId': 722, 'movieId': 590, 'rating': 1.7, 'timestamp': 1745999800}
# 329
# {'userId': 567, 'movieId': 419, 'rating': 3.4, 'timestamp': 1745999804}
# 330
# {'userId': 495, 'movieId': 522, 'rating': 3.5, 'timestamp': 1745999806}
# 331
# {'userId': 683, 'movieId': 203, 'rating': 3.7, 'timestamp': 1745999809}
# 332
# {'userId': 571, 'movieId': 867, 'rating': 2.8, 'timestamp': 1745999814}
# 333
# {'userId': 748, 'movieId': 727, 'rating': 0.5, 'timestamp': 1745999818}
# 334
# {'userId': 845, 'movieId': 161, 'rating': 2.8, 'timestamp': 1745999823}
# 335
# {'userId': 270, 'movieId': 366, 'rating': 1.5, 'timestamp': 1745999827}
# 336
# {'userId': 577, 'movieId': 105, 'rating': 1.1, 'timestamp': 1745999831}
# 337
# {'userId': 194, 'movieId': 483, 'rating': 1.0, 'timestamp': 1745999834}
# 338
# {'userId': 532, 'movieId': 712, 'rating': 2.2, 'timestamp': 1745999839}
# 339
# {'userId': 903, 'movieId': 105, 'rating': 3.1, 'timestamp': 1745999841}
# 340
# {'userId': 834, 'movieId': 787, 'rating': 1.4, 'timestamp': 1745999844}
# 341
# {'userId': 508, 'movieId': 672, 'rating': 2.7, 'timestamp': 1745999846}
# 342
# {'userId': 947, 'movieId': 345, 'rating': 0.6, 'timestamp': 1745999850}
# 343
# {'userId': 912, 'movieId': 328, 'rating': 3.5, 'timestamp': 1745999857}
# 344
# {'userId': 537, 'movieId': 612, 'rating': 1.5, 'timestamp': 1745999860}
# 345
# {'userId': 512, 'movieId': 364, 'rating': 2.0, 'timestamp': 1745999865}
# 346
# {'userId': 775, 'movieId': 444, 'rating': 3.0, 'timestamp': 1745999869}
# 347
# {'userId': 1, 'movieId': 373, 'rating': 0.6, 'timestamp': 1745999872}
# 348
# {'userId': 727, 'movieId': 133, 'rating': 0.7, 'timestamp': 1745999876}
# 349
# {'userId': 791, 'movieId': 471, 'rating': 3.5, 'timestamp': 1745999878}
# 350
# {'userId': 393, 'movieId': 350, 'rating': 3.5, 'timestamp': 1745999882}
# 351
# {'userId': 747, 'movieId': 497, 'rating': 3.0, 'timestamp': 1745999884}
# 352
# {'userId': 844, 'movieId': 539, 'rating': 2.4, 'timestamp': 1745999892}
# 353
# {'userId': 805, 'movieId': 209, 'rating': 4.0, 'timestamp': 1745999895}
# 354
# {'userId': 898, 'movieId': 473, 'rating': 3.6, 'timestamp': 1745999897}
# 355
# {'userId': 575, 'movieId': 838, 'rating': 3.5, 'timestamp': 1745999901}
# 356
# {'userId': 999, 'movieId': 355, 'rating': 1.9, 'timestamp': 1745999904}
# 357
# {'userId': 489, 'movieId': 938, 'rating': 3.6, 'timestamp': 1745999906}
# 358
# {'userId': 268, 'movieId': 992, 'rating': 0.8, 'timestamp': 1745999909}
# 359
# {'userId': 175, 'movieId': 162, 'rating': 0.9, 'timestamp': 1745999913}
# 360
# {'userId': 38, 'movieId': 601, 'rating': 1.9, 'timestamp': 1745999917}
# 361
# {'userId': 166, 'movieId': 551, 'rating': 3.7, 'timestamp': 1745999923}
# 362
# {'userId': 465, 'movieId': 322, 'rating': 3.0, 'timestamp': 1745999926}
# 363
# {'userId': 268, 'movieId': 859, 'rating': 1.1, 'timestamp': 1745999929}
# 364
# {'userId': 51, 'movieId': 956, 'rating': 1.4, 'timestamp': 1745999931}
# 365
# {'userId': 54, 'movieId': 994, 'rating': 2.0, 'timestamp': 1745999936}
# 366
# {'userId': 34, 'movieId': 353, 'rating': 1.4, 'timestamp': 1745999938}
# 367
# {'userId': 652, 'movieId': 380, 'rating': 4.7, 'timestamp': 1745999940}
# 368
# {'userId': 476, 'movieId': 392, 'rating': 3.2, 'timestamp': 1745999943}
# 369
# {'userId': 180, 'movieId': 173, 'rating': 2.7, 'timestamp': 1745999948}
# 370
# {'userId': 823, 'movieId': 438, 'rating': 3.9, 'timestamp': 1745999956}
# 371
# {'userId': 183, 'movieId': 468, 'rating': 2.5, 'timestamp': 1745999961}
# 372
# {'userId': 816, 'movieId': 702, 'rating': 4.9, 'timestamp': 1745999963}
# 373
# {'userId': 269, 'movieId': 397, 'rating': 2.7, 'timestamp': 1745999966}
# 374
# {'userId': 276, 'movieId': 843, 'rating': 3.2, 'timestamp': 1745999970}
# 375
# {'userId': 40, 'movieId': 518, 'rating': 3.7, 'timestamp': 1745999973}
# 376
# {'userId': 405, 'movieId': 893, 'rating': 1.4, 'timestamp': 1745999976}
# 377
# {'userId': 979, 'movieId': 556, 'rating': 1.7, 'timestamp': 1745999981}
# 378
# {'userId': 168, 'movieId': 217, 'rating': 2.4, 'timestamp': 1745999988}
# 379
# {'userId': 476, 'movieId': 670, 'rating': 3.0, 'timestamp': 1745999992}
# 380
# {'userId': 231, 'movieId': 865, 'rating': 2.3, 'timestamp': 1745999994}
# 381
# {'userId': 316, 'movieId': 600, 'rating': 2.9, 'timestamp': 1745999999}
# 382
# {'userId': 84, 'movieId': 898, 'rating': 3.3, 'timestamp': 1746000003}
# 383
# {'userId': 880, 'movieId': 894, 'rating': 2.2, 'timestamp': 1746000007}
# 384
# {'userId': 705, 'movieId': 462, 'rating': 2.9, 'timestamp': 1746000012}
# 385
# {'userId': 246, 'movieId': 254, 'rating': 4.4, 'timestamp': 1746000016}
# 386
# {'userId': 328, 'movieId': 431, 'rating': 0.9, 'timestamp': 1746000022}
# 387
# {'userId': 936, 'movieId': 447, 'rating': 1.7, 'timestamp': 1746000026}
# 388
# {'userId': 470, 'movieId': 173, 'rating': 2.1, 'timestamp': 1746000029}
# 389
# {'userId': 569, 'movieId': 371, 'rating': 1.9, 'timestamp': 1746000033}
# 390
# {'userId': 910, 'movieId': 425, 'rating': 0.7, 'timestamp': 1746000035}
# 391
# {'userId': 643, 'movieId': 416, 'rating': 3.9, 'timestamp': 1746000038}
# 392
# {'userId': 694, 'movieId': 527, 'rating': 3.9, 'timestamp': 1746000040}
# 393
# {'userId': 483, 'movieId': 74, 'rating': 3.0, 'timestamp': 1746000044}
# 394
# {'userId': 271, 'movieId': 638, 'rating': 3.9, 'timestamp': 1746000048}
# 395
# {'userId': 874, 'movieId': 705, 'rating': 3.7, 'timestamp': 1746000054}
# 396
# {'userId': 269, 'movieId': 58, 'rating': 3.7, 'timestamp': 1746000058}
# 397
# {'userId': 747, 'movieId': 458, 'rating': 1.8, 'timestamp': 1746000060}
# 398
# {'userId': 223, 'movieId': 212, 'rating': 1.4, 'timestamp': 1746000062}
# 399
# {'userId': 841, 'movieId': 1, 'rating': 1.6, 'timestamp': 1746000067}
# 400
# {'userId': 719, 'movieId': 831, 'rating': 1.3, 'timestamp': 1746000071}
# 401
# {'userId': 653, 'movieId': 410, 'rating': 0.9, 'timestamp': 1746000074}
# 402
# {'userId': 167, 'movieId': 885, 'rating': 1.5, 'timestamp': 1746000078}
# 403
# {'userId': 456, 'movieId': 34, 'rating': 3.5, 'timestamp': 1746000080}
# 404
# {'userId': 478, 'movieId': 139, 'rating': 0.9, 'timestamp': 1746000086}
# 405
# {'userId': 841, 'movieId': 678, 'rating': 3.0, 'timestamp': 1746000090}
# 406
# {'userId': 192, 'movieId': 347, 'rating': 1.6, 'timestamp': 1746000093}
# 407
# {'userId': 704, 'movieId': 631, 'rating': 3.0, 'timestamp': 1746000095}
# 408
# {'userId': 274, 'movieId': 60, 'rating': 4.7, 'timestamp': 1746000099}
# 409
# {'userId': 898, 'movieId': 823, 'rating': 4.6, 'timestamp': 1746000103}
# 410
# {'userId': 115, 'movieId': 139, 'rating': 2.6, 'timestamp': 1746000107}
# 411
# {'userId': 419, 'movieId': 217, 'rating': 4.1, 'timestamp': 1746000110}
# 412
# {'userId': 707, 'movieId': 639, 'rating': 5.0, 'timestamp': 1746000114}
# 413
# {'userId': 80, 'movieId': 386, 'rating': 4.9, 'timestamp': 1746000120}
# 414
# {'userId': 457, 'movieId': 457, 'rating': 3.5, 'timestamp': 1746000124}
# 415
# {'userId': 876, 'movieId': 931, 'rating': 3.7, 'timestamp': 1746000128}
# 416
# {'userId': 203, 'movieId': 766, 'rating': 1.4, 'timestamp': 1746000133}
# 417
# {'userId': 747, 'movieId': 557, 'rating': 2.8, 'timestamp': 1746000137}
# 418
# {'userId': 322, 'movieId': 92, 'rating': 2.8, 'timestamp': 1746000142}
# 419
# {'userId': 424, 'movieId': 174, 'rating': 2.0, 'timestamp': 1746000145}
# 420
# {'userId': 264, 'movieId': 276, 'rating': 1.1, 'timestamp': 1746000150}
# 421
# {'userId': 885, 'movieId': 767, 'rating': 0.8, 'timestamp': 1746000153}
# 422
# {'userId': 735, 'movieId': 86, 'rating': 4.7, 'timestamp': 1746000158}
# 423
# {'userId': 564, 'movieId': 402, 'rating': 3.7, 'timestamp': 1746000161}
# 424
# {'userId': 250, 'movieId': 347, 'rating': 1.1, 'timestamp': 1746000163}
# 425
# {'userId': 288, 'movieId': 754, 'rating': 1.1, 'timestamp': 1746000166}
# 426
# {'userId': 373, 'movieId': 764, 'rating': 4.6, 'timestamp': 1746000169}
# 427
# {'userId': 169, 'movieId': 590, 'rating': 3.6, 'timestamp': 1746000174}
# 428
# {'userId': 62, 'movieId': 82, 'rating': 2.2, 'timestamp': 1746000176}
# 429
# {'userId': 166, 'movieId': 847, 'rating': 3.9, 'timestamp': 1746000183}
# 430
# {'userId': 887, 'movieId': 343, 'rating': 2.2, 'timestamp': 1746000188}
# 431
# {'userId': 397, 'movieId': 408, 'rating': 3.4, 'timestamp': 1746000193}
# 432
# {'userId': 867, 'movieId': 880, 'rating': 2.5, 'timestamp': 1746000196}
# 433
# {'userId': 674, 'movieId': 127, 'rating': 1.1, 'timestamp': 1746000200}
# 434
# {'userId': 412, 'movieId': 713, 'rating': 4.3, 'timestamp': 1746000203}
# 435
# {'userId': 780, 'movieId': 438, 'rating': 3.0, 'timestamp': 1746000206}
# 436
# {'userId': 377, 'movieId': 693, 'rating': 2.5, 'timestamp': 1746000211}
# 437
# {'userId': 39, 'movieId': 152, 'rating': 1.7, 'timestamp': 1746000217}
# 438
# {'userId': 661, 'movieId': 772, 'rating': 3.5, 'timestamp': 1746000219}
# 439
# {'userId': 806, 'movieId': 329, 'rating': 1.6, 'timestamp': 1746000224}
# 440
# {'userId': 10, 'movieId': 659, 'rating': 1.7, 'timestamp': 1746000228}
# 441
# {'userId': 299, 'movieId': 42, 'rating': 4.3, 'timestamp': 1746000233}
# 442
# {'userId': 453, 'movieId': 101, 'rating': 4.0, 'timestamp': 1746000237}
# 443
# {'userId': 82, 'movieId': 563, 'rating': 1.1, 'timestamp': 1746000240}
# 444
# {'userId': 5, 'movieId': 123, 'rating': 4.0, 'timestamp': 1746000243}
# 445
# {'userId': 275, 'movieId': 117, 'rating': 3.4, 'timestamp': 1746000250}
# 446
# {'userId': 815, 'movieId': 789, 'rating': 0.5, 'timestamp': 1746000253}
# 447
# {'userId': 459, 'movieId': 439, 'rating': 1.4, 'timestamp': 1746000257}
# 448
# {'userId': 651, 'movieId': 217, 'rating': 2.9, 'timestamp': 1746000261}
# 449
# {'userId': 962, 'movieId': 913, 'rating': 2.3, 'timestamp': 1746000265}
# 450
# {'userId': 389, 'movieId': 185, 'rating': 4.7, 'timestamp': 1746000268}
# 451
# {'userId': 378, 'movieId': 158, 'rating': 3.0, 'timestamp': 1746000270}
# 452
# {'userId': 89, 'movieId': 557, 'rating': 1.3, 'timestamp': 1746000275}
# 453
# {'userId': 533, 'movieId': 826, 'rating': 4.7, 'timestamp': 1746000282}
# 454
# {'userId': 175, 'movieId': 961, 'rating': 3.3, 'timestamp': 1746000284}
# 455
# {'userId': 292, 'movieId': 718, 'rating': 3.3, 'timestamp': 1746000289}
# 456
# {'userId': 586, 'movieId': 378, 'rating': 4.3, 'timestamp': 1746000292}
# 457
# {'userId': 449, 'movieId': 128, 'rating': 2.9, 'timestamp': 1746000297}
# 458
# {'userId': 567, 'movieId': 396, 'rating': 0.7, 'timestamp': 1746000301}
# 459
# {'userId': 887, 'movieId': 203, 'rating': 0.7, 'timestamp': 1746000303}
# 460
# {'userId': 301, 'movieId': 971, 'rating': 1.0, 'timestamp': 1746000306}
# 461
# {'userId': 493, 'movieId': 354, 'rating': 4.8, 'timestamp': 1746000309}
# 462
# {'userId': 93, 'movieId': 386, 'rating': 3.9, 'timestamp': 1746000316}
# 463
# {'userId': 55, 'movieId': 623, 'rating': 0.5, 'timestamp': 1746000319}
# 464
# {'userId': 517, 'movieId': 974, 'rating': 1.1, 'timestamp': 1746000322}
# 465
# {'userId': 941, 'movieId': 348, 'rating': 3.2, 'timestamp': 1746000325}
# 466
# {'userId': 925, 'movieId': 940, 'rating': 1.8, 'timestamp': 1746000328}
# 467
# {'userId': 204, 'movieId': 596, 'rating': 2.8, 'timestamp': 1746000333}
# 468
# {'userId': 452, 'movieId': 758, 'rating': 2.8, 'timestamp': 1746000335}
# 469
# {'userId': 501, 'movieId': 410, 'rating': 1.9, 'timestamp': 1746000339}
# 470
# {'userId': 111, 'movieId': 337, 'rating': 3.3, 'timestamp': 1746000343}
# 471
# {'userId': 193, 'movieId': 566, 'rating': 3.7, 'timestamp': 1746000349}
# 472
# {'userId': 863, 'movieId': 412, 'rating': 2.2, 'timestamp': 1746000354}
# 473
# {'userId': 185, 'movieId': 611, 'rating': 2.2, 'timestamp': 1746000356}
# 474
# {'userId': 286, 'movieId': 951, 'rating': 1.9, 'timestamp': 1746000360}
# 475
# {'userId': 383, 'movieId': 653, 'rating': 3.0, 'timestamp': 1746000364}
# 476
# {'userId': 851, 'movieId': 982, 'rating': 1.7, 'timestamp': 1746000368}
# 477
# {'userId': 766, 'movieId': 384, 'rating': 3.0, 'timestamp': 1746000373}
# 478
# {'userId': 193, 'movieId': 54, 'rating': 1.1, 'timestamp': 1746000380}
# 479
# {'userId': 605, 'movieId': 944, 'rating': 2.9, 'timestamp': 1746000383}
# 480
# {'userId': 536, 'movieId': 842, 'rating': 3.9, 'timestamp': 1746000385}
# 481
# {'userId': 870, 'movieId': 83, 'rating': 3.7, 'timestamp': 1746000388}
# 482
# {'userId': 32, 'movieId': 347, 'rating': 4.5, 'timestamp': 1746000392}
# 483
# {'userId': 473, 'movieId': 777, 'rating': 3.2, 'timestamp': 1746000395}
# 484
# {'userId': 379, 'movieId': 817, 'rating': 0.9, 'timestamp': 1746000398}
# 485
# {'userId': 842, 'movieId': 605, 'rating': 4.0, 'timestamp': 1746000403}
# 486
# {'userId': 570, 'movieId': 162, 'rating': 1.0, 'timestamp': 1746000406}
# 487
# {'userId': 656, 'movieId': 917, 'rating': 4.0, 'timestamp': 1746000413}
# 488
# {'userId': 449, 'movieId': 645, 'rating': 2.1, 'timestamp': 1746000415}
# 489
# {'userId': 282, 'movieId': 303, 'rating': 2.2, 'timestamp': 1746000418}
# 490
# {'userId': 244, 'movieId': 513, 'rating': 2.6, 'timestamp': 1746000421}
# 491
# {'userId': 333, 'movieId': 555, 'rating': 2.4, 'timestamp': 1746000426}
# 492
# {'userId': 802, 'movieId': 702, 'rating': 1.1, 'timestamp': 1746000430}
# 493
# {'userId': 910, 'movieId': 81, 'rating': 1.9, 'timestamp': 1746000433}
# 494
# {'userId': 180, 'movieId': 432, 'rating': 1.8, 'timestamp': 1746000435}
# 495
# {'userId': 145, 'movieId': 0, 'rating': 0.9, 'timestamp': 1746000438}
# 496
# {'userId': 543, 'movieId': 508, 'rating': 1.8, 'timestamp': 1746000441}
# 497
# {'userId': 205, 'movieId': 306, 'rating': 3.9, 'timestamp': 1746000449}
# 498
# {'userId': 515, 'movieId': 793, 'rating': 3.4, 'timestamp': 1746000452}
# 499
# {'userId': 865, 'movieId': 283, 'rating': 2.1, 'timestamp': 1746000457}
# 500
# {'userId': 197, 'movieId': 515, 'rating': 2.1, 'timestamp': 1746000460}
# 501
# {'userId': 398, 'movieId': 748, 'rating': 4.4, 'timestamp': 1746000463}
# 502
# {'userId': 982, 'movieId': 971, 'rating': 0.8, 'timestamp': 1746000465}
# 503
# {'userId': 18, 'movieId': 981, 'rating': 4.6, 'timestamp': 1746000468}
# 504
# {'userId': 984, 'movieId': 379, 'rating': 0.8, 'timestamp': 1746000471}
# 505
# {'userId': 907, 'movieId': 336, 'rating': 3.4, 'timestamp': 1746000475}
# 506
# {'userId': 571, 'movieId': 348, 'rating': 3.9, 'timestamp': 1746000482}
# 507
# {'userId': 2, 'movieId': 166, 'rating': 2.6, 'timestamp': 1746000484}
# 508
# {'userId': 755, 'movieId': 302, 'rating': 0.9, 'timestamp': 1746000487}
# 509
# {'userId': 86, 'movieId': 254, 'rating': 5.0, 'timestamp': 1746000491}
# 510
# {'userId': 370, 'movieId': 151, 'rating': 1.5, 'timestamp': 1746000495}
# 511
# {'userId': 385, 'movieId': 163, 'rating': 1.7, 'timestamp': 1746000498}
# 512
# {'userId': 336, 'movieId': 404, 'rating': 3.9, 'timestamp': 1746000503}
# 513
# {'userId': 792, 'movieId': 804, 'rating': 3.3, 'timestamp': 1746000507}
# 514
# {'userId': 627, 'movieId': 934, 'rating': 0.8, 'timestamp': 1746000512}
# 515
# {'userId': 872, 'movieId': 789, 'rating': 0.6, 'timestamp': 1746000517}
# 516
# {'userId': 912, 'movieId': 690, 'rating': 3.4, 'timestamp': 1746000521}
# 517
# {'userId': 130, 'movieId': 809, 'rating': 4.0, 'timestamp': 1746000524}
# 518
# {'userId': 531, 'movieId': 86, 'rating': 3.3, 'timestamp': 1746000529}
# 519
# {'userId': 570, 'movieId': 67, 'rating': 3.3, 'timestamp': 1746000533}
# 520
# {'userId': 4, 'movieId': 83, 'rating': 2.3, 'timestamp': 1746000538}
# 521
# {'userId': 631, 'movieId': 984, 'rating': 4.5, 'timestamp': 1746000543}
# 522
# {'userId': 195, 'movieId': 566, 'rating': 2.7, 'timestamp': 1746000547}
# 523
# {'userId': 918, 'movieId': 180, 'rating': 1.8, 'timestamp': 1746000552}
# 524
# {'userId': 186, 'movieId': 467, 'rating': 2.2, 'timestamp': 1746000554}
# 525
# {'userId': 626, 'movieId': 894, 'rating': 1.5, 'timestamp': 1746000559}
# 526
# {'userId': 580, 'movieId': 855, 'rating': 2.0, 'timestamp': 1746000563}
# 527
# {'userId': 751, 'movieId': 916, 'rating': 1.2, 'timestamp': 1746000565}
# 528
# {'userId': 865, 'movieId': 730, 'rating': 1.8, 'timestamp': 1746000569}
# 529
# {'userId': 511, 'movieId': 825, 'rating': 4.4, 'timestamp': 1746000571}
# 530
# {'userId': 384, 'movieId': 408, 'rating': 1.4, 'timestamp': 1746000576}
# 531
# {'userId': 20, 'movieId': 902, 'rating': 1.9, 'timestamp': 1746000581}
# 532
# {'userId': 342, 'movieId': 138, 'rating': 4.7, 'timestamp': 1746000585}
# 533
# {'userId': 619, 'movieId': 534, 'rating': 3.2, 'timestamp': 1746000590}
# 534
# {'userId': 704, 'movieId': 574, 'rating': 4.7, 'timestamp': 1746000594}
# 535
# {'userId': 381, 'movieId': 580, 'rating': 3.2, 'timestamp': 1746000597}
# 536
# {'userId': 824, 'movieId': 399, 'rating': 3.3, 'timestamp': 1746000602}
# 537
# {'userId': 158, 'movieId': 843, 'rating': 1.4, 'timestamp': 1746000604}
# 538
# {'userId': 957, 'movieId': 404, 'rating': 3.9, 'timestamp': 1746000611}
# 539
# {'userId': 957, 'movieId': 294, 'rating': 4.0, 'timestamp': 1746000616}
# 540
# {'userId': 230, 'movieId': 262, 'rating': 3.0, 'timestamp': 1746000620}
# 541
# {'userId': 57, 'movieId': 365, 'rating': 3.0, 'timestamp': 1746000624}
# 542
# {'userId': 394, 'movieId': 182, 'rating': 1.5, 'timestamp': 1746000627}
# 543
# {'userId': 883, 'movieId': 674, 'rating': 1.8, 'timestamp': 1746000631}
# 544
# {'userId': 743, 'movieId': 112, 'rating': 2.2, 'timestamp': 1746000634}
# 545
# {'userId': 421, 'movieId': 923, 'rating': 4.6, 'timestamp': 1746000641}
# 546
# {'userId': 39, 'movieId': 598, 'rating': 3.1, 'timestamp': 1746000645}
# 547
# {'userId': 841, 'movieId': 58, 'rating': 1.5, 'timestamp': 1746000649}
# 548
# {'userId': 463, 'movieId': 857, 'rating': 1.0, 'timestamp': 1746000652}
# 549
# {'userId': 920, 'movieId': 581, 'rating': 2.0, 'timestamp': 1746000654}
# 550
# {'userId': 959, 'movieId': 239, 'rating': 2.4, 'timestamp': 1746000656}
# 551
# {'userId': 222, 'movieId': 459, 'rating': 1.8, 'timestamp': 1746000661}
# 552
# {'userId': 275, 'movieId': 662, 'rating': 1.1, 'timestamp': 1746000664}
# 553
# {'userId': 347, 'movieId': 403, 'rating': 0.7, 'timestamp': 1746000667}
# 554
# {'userId': 563, 'movieId': 375, 'rating': 3.9, 'timestamp': 1746000669}
# 555
# {'userId': 338, 'movieId': 745, 'rating': 1.1, 'timestamp': 1746000677}
# 556
# {'userId': 458, 'movieId': 666, 'rating': 3.7, 'timestamp': 1746000680}
# 557
# {'userId': 300, 'movieId': 653, 'rating': 1.1, 'timestamp': 1746000683}
# 558
# {'userId': 319, 'movieId': 658, 'rating': 4.1, 'timestamp': 1746000685}
# 559
# {'userId': 323, 'movieId': 944, 'rating': 4.2, 'timestamp': 1746000690}
# 560
# {'userId': 793, 'movieId': 62, 'rating': 1.4, 'timestamp': 1746000693}
# 561
# {'userId': 560, 'movieId': 118, 'rating': 3.2, 'timestamp': 1746000696}
# 562
# {'userId': 107, 'movieId': 383, 'rating': 2.5, 'timestamp': 1746000700}
# 563
# {'userId': 61, 'movieId': 296, 'rating': 1.8, 'timestamp': 1746000702}
# 564
# {'userId': 601, 'movieId': 690, 'rating': 2.9, 'timestamp': 1746000710}
# 565
# {'userId': 377, 'movieId': 239, 'rating': 2.3, 'timestamp': 1746000712}
# 566
# {'userId': 713, 'movieId': 786, 'rating': 1.5, 'timestamp': 1746000715}
# 567
# {'userId': 344, 'movieId': 288, 'rating': 4.3, 'timestamp': 1746000719}
# 568
# {'userId': 796, 'movieId': 44, 'rating': 1.2, 'timestamp': 1746000723}
# 569
# {'userId': 330, 'movieId': 133, 'rating': 4.7, 'timestamp': 1746000725}
# 570
# {'userId': 515, 'movieId': 498, 'rating': 4.1, 'timestamp': 1746000729}
# 571
# {'userId': 584, 'movieId': 803, 'rating': 2.6, 'timestamp': 1746000733}
# 572
# {'userId': 382, 'movieId': 187, 'rating': 1.0, 'timestamp': 1746000741}
# 573
# {'userId': 661, 'movieId': 688, 'rating': 2.6, 'timestamp': 1746000745}
# 574
# {'userId': 967, 'movieId': 253, 'rating': 1.3, 'timestamp': 1746000748}
# 575
# {'userId': 759, 'movieId': 890, 'rating': 4.3, 'timestamp': 1746000750}
# 576
# {'userId': 539, 'movieId': 284, 'rating': 3.0, 'timestamp': 1746000752}
# 577
# {'userId': 568, 'movieId': 80, 'rating': 3.7, 'timestamp': 1746000756}
# 578
# {'userId': 829, 'movieId': 835, 'rating': 4.1, 'timestamp': 1746000759}
# 579
# {'userId': 678, 'movieId': 120, 'rating': 0.7, 'timestamp': 1746000761}
# 580
# {'userId': 890, 'movieId': 214, 'rating': 2.8, 'timestamp': 1746000765}
# 581
# {'userId': 826, 'movieId': 409, 'rating': 1.5, 'timestamp': 1746000769}
# 582
# {'userId': 753, 'movieId': 965, 'rating': 0.6, 'timestamp': 1746000774}
# 583
# {'userId': 268, 'movieId': 667, 'rating': 4.5, 'timestamp': 1746000778}
# 584
# {'userId': 588, 'movieId': 203, 'rating': 2.1, 'timestamp': 1746000782}
# 585
# {'userId': 390, 'movieId': 844, 'rating': 1.7, 'timestamp': 1746000785}
# 586
# {'userId': 373, 'movieId': 842, 'rating': 0.9, 'timestamp': 1746000790}
# 587
# {'userId': 100, 'movieId': 157, 'rating': 1.6, 'timestamp': 1746000792}
# 588
# {'userId': 484, 'movieId': 785, 'rating': 1.3, 'timestamp': 1746000795}
# 589
# {'userId': 128, 'movieId': 891, 'rating': 1.8, 'timestamp': 1746000797}
# 590
# {'userId': 305, 'movieId': 853, 'rating': 0.9, 'timestamp': 1746000799}
# 591
# {'userId': 794, 'movieId': 771, 'rating': 2.3, 'timestamp': 1746000806}
# 592
# {'userId': 874, 'movieId': 627, 'rating': 1.8, 'timestamp': 1746000810}
# 593
# {'userId': 912, 'movieId': 640, 'rating': 3.3, 'timestamp': 1746000812}
# 594
# {'userId': 53, 'movieId': 47, 'rating': 2.2, 'timestamp': 1746000815}
# 595
# {'userId': 919, 'movieId': 487, 'rating': 1.8, 'timestamp': 1746000817}
# 596
# {'userId': 104, 'movieId': 389, 'rating': 4.8, 'timestamp': 1746000821}
# 597
# {'userId': 646, 'movieId': 251, 'rating': 0.9, 'timestamp': 1746000823}
# 598
# {'userId': 154, 'movieId': 133, 'rating': 2.2, 'timestamp': 1746000828}
# 599
# {'userId': 264, 'movieId': 991, 'rating': 1.0, 'timestamp': 1746000831}
# 600
# {'userId': 268, 'movieId': 789, 'rating': 2.7, 'timestamp': 1746000838}
# 601
# {'userId': 667, 'movieId': 555, 'rating': 2.5, 'timestamp': 1746000841}
# 602
# {'userId': 339, 'movieId': 746, 'rating': 1.4, 'timestamp': 1746000845}
# 603
# {'userId': 653, 'movieId': 978, 'rating': 2.1, 'timestamp': 1746000847}
# 604
# {'userId': 58, 'movieId': 580, 'rating': 5.0, 'timestamp': 1746000850}
# 605
# {'userId': 608, 'movieId': 554, 'rating': 2.7, 'timestamp': 1746000853}
# 606
# {'userId': 474, 'movieId': 469, 'rating': 4.8, 'timestamp': 1746000857}
# 607
# {'userId': 409, 'movieId': 325, 'rating': 1.8, 'timestamp': 1746000861}
# 608
# {'userId': 978, 'movieId': 190, 'rating': 4.0, 'timestamp': 1746000865}
# 609
# {'userId': 536, 'movieId': 479, 'rating': 3.4, 'timestamp': 1746000872}
# 610
# {'userId': 326, 'movieId': 190, 'rating': 4.7, 'timestamp': 1746000874}
# 611
# {'userId': 919, 'movieId': 363, 'rating': 0.7, 'timestamp': 1746000878}
# 612
# {'userId': 909, 'movieId': 167, 'rating': 0.7, 'timestamp': 1746000883}
# 613
# {'userId': 18, 'movieId': 462, 'rating': 0.8, 'timestamp': 1746000886}
# 614
# {'userId': 554, 'movieId': 44, 'rating': 0.8, 'timestamp': 1746000890}
# 615
# {'userId': 913, 'movieId': 485, 'rating': 0.8, 'timestamp': 1746000894}
# 616
# {'userId': 116, 'movieId': 364, 'rating': 1.4, 'timestamp': 1746000898}
# 617
# {'userId': 134, 'movieId': 726, 'rating': 2.3, 'timestamp': 1746000904}
# 618
# {'userId': 103, 'movieId': 998, 'rating': 4.1, 'timestamp': 1746000906}
# 619
# {'userId': 802, 'movieId': 902, 'rating': 1.2, 'timestamp': 1746000908}
# 620
# {'userId': 913, 'movieId': 462, 'rating': 4.8, 'timestamp': 1746000912}
# 621
# {'userId': 224, 'movieId': 592, 'rating': 2.7, 'timestamp': 1746000914}
# 622
# {'userId': 786, 'movieId': 908, 'rating': 3.2, 'timestamp': 1746000918}
# 623
# {'userId': 515, 'movieId': 546, 'rating': 1.9, 'timestamp': 1746000921}
# 624
# {'userId': 306, 'movieId': 290, 'rating': 3.9, 'timestamp': 1746000925}
# 625
# {'userId': 196, 'movieId': 582, 'rating': 2.9, 'timestamp': 1746000929}
# 626
# {'userId': 949, 'movieId': 772, 'rating': 4.6, 'timestamp': 1746000936}
# 627
# {'userId': 78, 'movieId': 615, 'rating': 4.6, 'timestamp': 1746000939}
# 628
# {'userId': 698, 'movieId': 993, 'rating': 3.1, 'timestamp': 1746000943}
# 629
# {'userId': 264, 'movieId': 580, 'rating': 4.1, 'timestamp': 1746000948}
# 630
# {'userId': 725, 'movieId': 821, 'rating': 4.0, 'timestamp': 1746000952}
# 631
# {'userId': 655, 'movieId': 644, 'rating': 1.6, 'timestamp': 1746000956}
# 632
# {'userId': 485, 'movieId': 512, 'rating': 4.1, 'timestamp': 1746000959}
# 633
# {'userId': 962, 'movieId': 5, 'rating': 4.9, 'timestamp': 1746000963}
# 634
# {'userId': 707, 'movieId': 452, 'rating': 4.4, 'timestamp': 1746000969}
# 635
# {'userId': 321, 'movieId': 145, 'rating': 0.9, 'timestamp': 1746000972}
# 636
# {'userId': 357, 'movieId': 195, 'rating': 3.6, 'timestamp': 1746000975}
# 637
# {'userId': 329, 'movieId': 507, 'rating': 3.6, 'timestamp': 1746000977}
# 638
# {'userId': 867, 'movieId': 191, 'rating': 1.5, 'timestamp': 1746000981}
# 639
# {'userId': 11, 'movieId': 303, 'rating': 3.1, 'timestamp': 1746000983}
# 640
# {'userId': 302, 'movieId': 299, 'rating': 2.0, 'timestamp': 1746000985}
# 641
# {'userId': 385, 'movieId': 278, 'rating': 1.0, 'timestamp': 1746000988}
# 642
# {'userId': 876, 'movieId': 940, 'rating': 3.2, 'timestamp': 1746000990}
# 643
# {'userId': 599, 'movieId': 310, 'rating': 3.8, 'timestamp': 1746000993}
# 644
# {'userId': 273, 'movieId': 722, 'rating': 1.8, 'timestamp': 1746000996}
# 645
# {'userId': 687, 'movieId': 647, 'rating': 3.0, 'timestamp': 1746001002}
# 646
# {'userId': 518, 'movieId': 444, 'rating': 3.3, 'timestamp': 1746001007}
# 647
# {'userId': 824, 'movieId': 793, 'rating': 1.7, 'timestamp': 1746001011}
# 648
# {'userId': 531, 'movieId': 673, 'rating': 2.7, 'timestamp': 1746001014}
# 649
# {'userId': 614, 'movieId': 205, 'rating': 1.2, 'timestamp': 1746001016}
# 650
# {'userId': 740, 'movieId': 894, 'rating': 0.6, 'timestamp': 1746001019}
# 651
# {'userId': 420, 'movieId': 320, 'rating': 1.4, 'timestamp': 1746001023}
# 652
# {'userId': 957, 'movieId': 781, 'rating': 2.1, 'timestamp': 1746001026}
# 653
# {'userId': 531, 'movieId': 811, 'rating': 2.0, 'timestamp': 1746001030}
# 654
# {'userId': 505, 'movieId': 932, 'rating': 4.2, 'timestamp': 1746001037}
# 655
# {'userId': 644, 'movieId': 618, 'rating': 1.5, 'timestamp': 1746001040}
# 656
# {'userId': 421, 'movieId': 99, 'rating': 3.5, 'timestamp': 1746001043}
# 657
# {'userId': 667, 'movieId': 6, 'rating': 1.8, 'timestamp': 1746001046}
# 658
# {'userId': 830, 'movieId': 173, 'rating': 1.7, 'timestamp': 1746001050}
# 659
# {'userId': 406, 'movieId': 479, 'rating': 3.7, 'timestamp': 1746001053}
# 660
# {'userId': 872, 'movieId': 164, 'rating': 3.9, 'timestamp': 1746001055}
# 661
# {'userId': 340, 'movieId': 93, 'rating': 3.8, 'timestamp': 1746001060}
# 662
# {'userId': 486, 'movieId': 143, 'rating': 3.1, 'timestamp': 1746001067}
# 663
# {'userId': 861, 'movieId': 597, 'rating': 2.3, 'timestamp': 1746001070}
# 664
# {'userId': 837, 'movieId': 425, 'rating': 2.3, 'timestamp': 1746001073}
# 665
# {'userId': 696, 'movieId': 743, 'rating': 1.5, 'timestamp': 1746001077}
# 666
# {'userId': 30, 'movieId': 651, 'rating': 3.9, 'timestamp': 1746001080}
# 667
# {'userId': 301, 'movieId': 114, 'rating': 4.7, 'timestamp': 1746001083}
# 668
# {'userId': 464, 'movieId': 640, 'rating': 3.6, 'timestamp': 1746001086}
# 669
# {'userId': 9, 'movieId': 473, 'rating': 1.8, 'timestamp': 1746001091}
# 670
# {'userId': 979, 'movieId': 259, 'rating': 2.5, 'timestamp': 1746001095}
# 671
# {'userId': 250, 'movieId': 975, 'rating': 4.9, 'timestamp': 1746001102}
# 672
# {'userId': 879, 'movieId': 409, 'rating': 1.0, 'timestamp': 1746001106}
# 673
# {'userId': 563, 'movieId': 531, 'rating': 2.6, 'timestamp': 1746001111}
# 674
# {'userId': 199, 'movieId': 307, 'rating': 4.1, 'timestamp': 1746001114}
# 675
# {'userId': 182, 'movieId': 848, 'rating': 0.6, 'timestamp': 1746001118}
# 676
# {'userId': 428, 'movieId': 95, 'rating': 3.5, 'timestamp': 1746001121}
# 677
# {'userId': 299, 'movieId': 865, 'rating': 3.8, 'timestamp': 1746001125}
# 678
# {'userId': 687, 'movieId': 467, 'rating': 3.2, 'timestamp': 1746001128}
# 679
# {'userId': 571, 'movieId': 224, 'rating': 5.0, 'timestamp': 1746001134}
# 680
# {'userId': 106, 'movieId': 253, 'rating': 1.3, 'timestamp': 1746001139}
# 681
# {'userId': 10, 'movieId': 334, 'rating': 1.6, 'timestamp': 1746001141}
# 682
# {'userId': 919, 'movieId': 542, 'rating': 1.0, 'timestamp': 1746001145}
# 683
# {'userId': 646, 'movieId': 410, 'rating': 0.8, 'timestamp': 1746001149}
# 684
# {'userId': 232, 'movieId': 51, 'rating': 2.0, 'timestamp': 1746001153}
# 685
# {'userId': 613, 'movieId': 881, 'rating': 3.9, 'timestamp': 1746001156}
# 686
# {'userId': 507, 'movieId': 394, 'rating': 0.8, 'timestamp': 1746001159}
# 687
# {'userId': 621, 'movieId': 558, 'rating': 3.9, 'timestamp': 1746001162}
# 688
# {'userId': 707, 'movieId': 399, 'rating': 0.7, 'timestamp': 1746001167}
# 689
# {'userId': 615, 'movieId': 436, 'rating': 2.5, 'timestamp': 1746001169}
# 690
# {'userId': 779, 'movieId': 862, 'rating': 1.7, 'timestamp': 1746001172}
# 691
# {'userId': 220, 'movieId': 728, 'rating': 1.4, 'timestamp': 1746001174}
# 692
# {'userId': 700, 'movieId': 249, 'rating': 3.3, 'timestamp': 1746001178}
# 693
# {'userId': 803, 'movieId': 703, 'rating': 4.7, 'timestamp': 1746001181}
# 694
# {'userId': 535, 'movieId': 396, 'rating': 4.1, 'timestamp': 1746001185}
# 695
# {'userId': 299, 'movieId': 148, 'rating': 2.5, 'timestamp': 1746001187}
# 696
# {'userId': 816, 'movieId': 602, 'rating': 3.3, 'timestamp': 1746001192}
# 697
# {'userId': 654, 'movieId': 559, 'rating': 4.8, 'timestamp': 1746001199}
# 698
# {'userId': 976, 'movieId': 516, 'rating': 4.2, 'timestamp': 1746001203}
# 699
# {'userId': 248, 'movieId': 466, 'rating': 3.1, 'timestamp': 1746001206}
# 700
# {'userId': 693, 'movieId': 577, 'rating': 2.9, 'timestamp': 1746001210}
# 701
# {'userId': 263, 'movieId': 897, 'rating': 3.6, 'timestamp': 1746001215}
# 702
# {'userId': 96, 'movieId': 943, 'rating': 4.9, 'timestamp': 1746001219}
# 703
# {'userId': 743, 'movieId': 356, 'rating': 1.7, 'timestamp': 1746001223}
# 704
# {'userId': 564, 'movieId': 612, 'rating': 3.7, 'timestamp': 1746001226}
# 705
# {'userId': 4, 'movieId': 131, 'rating': 1.6, 'timestamp': 1746001232}
# 706
# {'userId': 420, 'movieId': 721, 'rating': 2.8, 'timestamp': 1746001235}
# 707
# {'userId': 768, 'movieId': 175, 'rating': 3.6, 'timestamp': 1746001239}
# 708
# {'userId': 920, 'movieId': 809, 'rating': 4.4, 'timestamp': 1746001243}
# 709
# {'userId': 142, 'movieId': 107, 'rating': 3.2, 'timestamp': 1746001247}
# 710
# {'userId': 940, 'movieId': 879, 'rating': 1.2, 'timestamp': 1746001250}
# 711
# {'userId': 695, 'movieId': 609, 'rating': 1.2, 'timestamp': 1746001252}
# 712
# {'userId': 646, 'movieId': 533, 'rating': 3.8, 'timestamp': 1746001255}
# 713
# {'userId': 924, 'movieId': 551, 'rating': 0.6, 'timestamp': 1746001260}
# 714
# {'userId': 222, 'movieId': 140, 'rating': 4.8, 'timestamp': 1746001266}
# 715
# {'userId': 722, 'movieId': 230, 'rating': 4.0, 'timestamp': 1746001269}
# 716
# {'userId': 149, 'movieId': 356, 'rating': 2.1, 'timestamp': 1746001273}
# 717
# {'userId': 283, 'movieId': 287, 'rating': 3.0, 'timestamp': 1746001278}
# 718
# {'userId': 458, 'movieId': 621, 'rating': 0.7, 'timestamp': 1746001282}
# 719
# {'userId': 974, 'movieId': 934, 'rating': 4.7, 'timestamp': 1746001285}
# 720
# {'userId': 807, 'movieId': 190, 'rating': 1.2, 'timestamp': 1746001288}
# 721
# {'userId': 753, 'movieId': 621, 'rating': 0.6, 'timestamp': 1746001292}
# 722
# {'userId': 763, 'movieId': 605, 'rating': 3.9, 'timestamp': 1746001298}
# 723
# {'userId': 190, 'movieId': 208, 'rating': 4.0, 'timestamp': 1746001300}
# 724
# {'userId': 765, 'movieId': 0, 'rating': 4.4, 'timestamp': 1746001304}
# 725
# {'userId': 918, 'movieId': 30, 'rating': 1.3, 'timestamp': 1746001307}
# 726
# {'userId': 478, 'movieId': 288, 'rating': 1.0, 'timestamp': 1746001311}
# 727
# {'userId': 518, 'movieId': 124, 'rating': 2.1, 'timestamp': 1746001314}
# 728
# {'userId': 0, 'movieId': 864, 'rating': 4.8, 'timestamp': 1746001318}
# 729
# {'userId': 811, 'movieId': 865, 'rating': 2.5, 'timestamp': 1746001322}
# 730
# {'userId': 189, 'movieId': 160, 'rating': 4.2, 'timestamp': 1746001325}
# 731
# {'userId': 826, 'movieId': 382, 'rating': 4.3, 'timestamp': 1746001331}
# 732
# {'userId': 456, 'movieId': 619, 'rating': 0.9, 'timestamp': 1746001334}
# 733
# {'userId': 541, 'movieId': 583, 'rating': 4.7, 'timestamp': 1746001338}
# 734
# {'userId': 545, 'movieId': 736, 'rating': 4.5, 'timestamp': 1746001341}
# 735
# {'userId': 300, 'movieId': 684, 'rating': 2.1, 'timestamp': 1746001345}
# 736
# {'userId': 607, 'movieId': 651, 'rating': 1.7, 'timestamp': 1746001347}
# 737
# {'userId': 642, 'movieId': 78, 'rating': 3.4, 'timestamp': 1746001352}
# 738
# {'userId': 309, 'movieId': 829, 'rating': 1.9, 'timestamp': 1746001354}
# 739
# {'userId': 102, 'movieId': 817, 'rating': 4.2, 'timestamp': 1746001357}
# 740
# {'userId': 913, 'movieId': 263, 'rating': 3.1, 'timestamp': 1746001364}
# 741
# {'userId': 727, 'movieId': 374, 'rating': 0.8, 'timestamp': 1746001368}
# 742
# {'userId': 872, 'movieId': 453, 'rating': 3.3, 'timestamp': 1746001371}
# 743
# {'userId': 994, 'movieId': 575, 'rating': 3.3, 'timestamp': 1746001375}
# 744
# {'userId': 588, 'movieId': 4, 'rating': 3.4, 'timestamp': 1746001379}
# 745
# {'userId': 393, 'movieId': 101, 'rating': 3.4, 'timestamp': 1746001382}
# 746
# {'userId': 203, 'movieId': 853, 'rating': 3.0, 'timestamp': 1746001386}
# 747
# {'userId': 826, 'movieId': 563, 'rating': 3.6, 'timestamp': 1746001390}
# 748
# {'userId': 453, 'movieId': 636, 'rating': 0.5, 'timestamp': 1746001397}
# 749
# {'userId': 972, 'movieId': 222, 'rating': 3.7, 'timestamp': 1746001402}
# 750
# {'userId': 238, 'movieId': 199, 'rating': 3.8, 'timestamp': 1746001404}
# 751
# {'userId': 559, 'movieId': 116, 'rating': 3.4, 'timestamp': 1746001408}
# 752
# {'userId': 198, 'movieId': 588, 'rating': 1.4, 'timestamp': 1746001412}
# 753
# {'userId': 738, 'movieId': 396, 'rating': 2.7, 'timestamp': 1746001416}
# 754
# {'userId': 553, 'movieId': 737, 'rating': 3.7, 'timestamp': 1746001421}
# 755
# {'userId': 958, 'movieId': 702, 'rating': 2.1, 'timestamp': 1746001423}
# 756
# {'userId': 224, 'movieId': 235, 'rating': 1.5, 'timestamp': 1746001429}
# 757
# {'userId': 974, 'movieId': 15, 'rating': 1.3, 'timestamp': 1746001432}
# 758
# {'userId': 956, 'movieId': 860, 'rating': 4.4, 'timestamp': 1746001436}
# 759
# {'userId': 882, 'movieId': 677, 'rating': 2.5, 'timestamp': 1746001440}
# 760
# {'userId': 920, 'movieId': 124, 'rating': 1.1, 'timestamp': 1746001443}
# 761
# {'userId': 596, 'movieId': 76, 'rating': 1.5, 'timestamp': 1746001446}
# 762
# {'userId': 564, 'movieId': 767, 'rating': 3.1, 'timestamp': 1746001449}
# 763
# {'userId': 141, 'movieId': 90, 'rating': 3.0, 'timestamp': 1746001452}
# 764
# {'userId': 403, 'movieId': 596, 'rating': 2.0, 'timestamp': 1746001455}
# 765
# {'userId': 908, 'movieId': 646, 'rating': 0.8, 'timestamp': 1746001462}
# 766
# {'userId': 624, 'movieId': 256, 'rating': 2.8, 'timestamp': 1746001466}
# 767
# {'userId': 602, 'movieId': 844, 'rating': 3.0, 'timestamp': 1746001469}
# 768
# {'userId': 596, 'movieId': 248, 'rating': 3.9, 'timestamp': 1746001472}
# 769
# {'userId': 596, 'movieId': 8, 'rating': 2.1, 'timestamp': 1746001474}
# 770
# {'userId': 767, 'movieId': 20, 'rating': 3.7, 'timestamp': 1746001476}
# 771
# {'userId': 140, 'movieId': 585, 'rating': 3.2, 'timestamp': 1746001480}
# 772
# {'userId': 101, 'movieId': 785, 'rating': 3.4, 'timestamp': 1746001484}
# 773
# {'userId': 746, 'movieId': 878, 'rating': 1.8, 'timestamp': 1746001488}
# 774
# {'userId': 954, 'movieId': 590, 'rating': 3.0, 'timestamp': 1746001494}
# 775
# {'userId': 407, 'movieId': 626, 'rating': 4.0, 'timestamp': 1746001498}
# 776
# {'userId': 19, 'movieId': 81, 'rating': 4.6, 'timestamp': 1746001501}
# 777
# {'userId': 307, 'movieId': 468, 'rating': 0.5, 'timestamp': 1746001506}
# 778
# {'userId': 911, 'movieId': 855, 'rating': 2.8, 'timestamp': 1746001508}
# 779
# {'userId': 827, 'movieId': 411, 'rating': 1.4, 'timestamp': 1746001510}
# 780
# {'userId': 252, 'movieId': 996, 'rating': 4.5, 'timestamp': 1746001514}
# 781
# ...
# 4931
# {'userId': 169, 'movieId': 742, 'rating': 2.2, 'timestamp': 1746017318}
# 4932
# {'userId': 31, 'movieId': 762, 'rating': 1.5, 'timestamp': 1746017322}
# 4933
# {'userId': 873, 'movieId': 943, 'rating': 0.6, 'timestamp': 1746017325}
# 4934
# {'userId': 307, 'movieId': 831, 'rating': 4.8, 'timestamp': 1746017328}
# 4935
# {'userId': 850, 'movieId': 778, 'rating': 1.1, 'timestamp': 1746017333}
# 4936
# {'userId': 294, 'movieId': 835, 'rating': 4.3, 'timestamp': 1746017337}
# 4937
# {'userId': 933, 'movieId': 17, 'rating': 3.3, 'timestamp': 1746017340}
# 4938
# {'userId': 190, 'movieId': 927, 'rating': 4.5, 'timestamp': 1746017343}
# 4939
# {'userId': 669, 'movieId': 484, 'rating': 1.0, 'timestamp': 1746017345}
# 4940
# {'userId': 979, 'movieId': 758, 'rating': 4.4, 'timestamp': 1746017348}
# 4941
# {'userId': 43, 'movieId': 954, 'rating': 1.8, 'timestamp': 1746017351}
# 4942
# {'userId': 913, 'movieId': 584, 'rating': 2.9, 'timestamp': 1746017353}
# 4943
# {'userId': 740, 'movieId': 832, 'rating': 2.1, 'timestamp': 1746017357}
# 4944
# {'userId': 718, 'movieId': 715, 'rating': 4.4, 'timestamp': 1746017360}
# 4945
# {'userId': 192, 'movieId': 11, 'rating': 2.5, 'timestamp': 1746017362}
# 4946
# {'userId': 922, 'movieId': 585, 'rating': 2.5, 'timestamp': 1746017367}
# 4947
# {'userId': 979, 'movieId': 803, 'rating': 2.2, 'timestamp': 1746017371}
# 4948
# {'userId': 532, 'movieId': 274, 'rating': 2.9, 'timestamp': 1746017375}
# 4949
# {'userId': 116, 'movieId': 899, 'rating': 1.3, 'timestamp': 1746017379}
# 4950
# {'userId': 388, 'movieId': 521, 'rating': 3.7, 'timestamp': 1746017384}
# 4951
# {'userId': 37, 'movieId': 647, 'rating': 4.7, 'timestamp': 1746017386}
# 4952
# {'userId': 572, 'movieId': 166, 'rating': 0.8, 'timestamp': 1746017390}
# 4953
# {'userId': 755, 'movieId': 458, 'rating': 3.1, 'timestamp': 1746017395}
# 4954
# {'userId': 601, 'movieId': 783, 'rating': 4.4, 'timestamp': 1746017398}
# 4955
# {'userId': 66, 'movieId': 946, 'rating': 1.1, 'timestamp': 1746017401}
# 4956
# {'userId': 680, 'movieId': 208, 'rating': 3.2, 'timestamp': 1746017404}
# 4957
# {'userId': 668, 'movieId': 876, 'rating': 1.1, 'timestamp': 1746017407}
# 4958
# {'userId': 278, 'movieId': 572, 'rating': 5.0, 'timestamp': 1746017409}
# 4959
# {'userId': 212, 'movieId': 654, 'rating': 2.9, 'timestamp': 1746017412}
# 4960
# {'userId': 64, 'movieId': 675, 'rating': 0.9, 'timestamp': 1746017417}
# 4961
# {'userId': 48, 'movieId': 420, 'rating': 4.6, 'timestamp': 1746017419}
# 4962
# {'userId': 213, 'movieId': 836, 'rating': 4.1, 'timestamp': 1746017422}
# 4963
# {'userId': 839, 'movieId': 766, 'rating': 3.8, 'timestamp': 1746017427}
# 4964
# {'userId': 92, 'movieId': 509, 'rating': 4.9, 'timestamp': 1746017430}
# 4965
# {'userId': 242, 'movieId': 693, 'rating': 2.8, 'timestamp': 1746017434}
# 4966
# {'userId': 532, 'movieId': 718, 'rating': 3.3, 'timestamp': 1746017438}
# 4967
# {'userId': 174, 'movieId': 258, 'rating': 3.4, 'timestamp': 1746017442}
# 4968
# {'userId': 757, 'movieId': 646, 'rating': 3.1, 'timestamp': 1746017446}
# 4969
# {'userId': 656, 'movieId': 190, 'rating': 1.9, 'timestamp': 1746017450}
# 4970
# {'userId': 902, 'movieId': 220, 'rating': 3.0, 'timestamp': 1746017452}
# 4971
# {'userId': 984, 'movieId': 63, 'rating': 4.6, 'timestamp': 1746017454}
# 4972
# {'userId': 981, 'movieId': 320, 'rating': 4.6, 'timestamp': 1746017457}
# 4973
# {'userId': 864, 'movieId': 341, 'rating': 1.7, 'timestamp': 1746017462}
# 4974
# {'userId': 501, 'movieId': 823, 'rating': 4.5, 'timestamp': 1746017466}
# 4975
# {'userId': 65, 'movieId': 718, 'rating': 1.5, 'timestamp': 1746017468}
# 4976
# {'userId': 491, 'movieId': 619, 'rating': 2.4, 'timestamp': 1746017472}
# 4977
# {'userId': 114, 'movieId': 779, 'rating': 3.7, 'timestamp': 1746017476}
# 4978
# {'userId': 432, 'movieId': 708, 'rating': 2.9, 'timestamp': 1746017478}
# 4979
# {'userId': 417, 'movieId': 37, 'rating': 2.0, 'timestamp': 1746017481}
# 4980
# {'userId': 775, 'movieId': 568, 'rating': 4.6, 'timestamp': 1746017484}
# 4981
# {'userId': 910, 'movieId': 513, 'rating': 2.8, 'timestamp': 1746017487}
# 4982
# {'userId': 411, 'movieId': 433, 'rating': 3.0, 'timestamp': 1746017492}
# 4983
# {'userId': 900, 'movieId': 634, 'rating': 1.3, 'timestamp': 1746017496}
# 4984
# {'userId': 892, 'movieId': 305, 'rating': 2.1, 'timestamp': 1746017499}
# 4985
# {'userId': 820, 'movieId': 547, 'rating': 2.1, 'timestamp': 1746017502}
# 4986
# {'userId': 588, 'movieId': 575, 'rating': 5.0, 'timestamp': 1746017507}
# 4987
# {'userId': 390, 'movieId': 166, 'rating': 0.6, 'timestamp': 1746017511}
# 4988
# {'userId': 348, 'movieId': 67, 'rating': 1.0, 'timestamp': 1746017516}
# 4989
# {'userId': 894, 'movieId': 75, 'rating': 4.9, 'timestamp': 1746017519}
# 4990
# {'userId': 383, 'movieId': 992, 'rating': 2.5, 'timestamp': 1746017523}
# 4991
# {'userId': 92, 'movieId': 376, 'rating': 2.3, 'timestamp': 1746017528}
# 4992
# {'userId': 250, 'movieId': 98, 'rating': 2.5, 'timestamp': 1746017533}
# 4993
# {'userId': 447, 'movieId': 498, 'rating': 2.5, 'timestamp': 1746017536}
# 4994
# {'userId': 702, 'movieId': 760, 'rating': 0.7, 'timestamp': 1746017541}
# 4995
# {'userId': 441, 'movieId': 195, 'rating': 1.9, 'timestamp': 1746017545}
# 4996
# {'userId': 622, 'movieId': 947, 'rating': 4.7, 'timestamp': 1746017550}
# 4997
# {'userId': 118, 'movieId': 56, 'rating': 3.5, 'timestamp': 1746017554}
# 4998
# {'userId': 27, 'movieId': 211, 'rating': 0.7, 'timestamp': 1746017559}
# 4999
# {'userId': 58, 'movieId': 657, 'rating': 0.8, 'timestamp': 1746017563}
# 5000
# {'userId': 593, 'movieId': 558, 'rating': 2.8, 'timestamp': 1746017565}
# 5001
# {'userId': 476, 'movieId': 807, 'rating': 2.4, 'timestamp': 1746017568}
# 5002
# {'userId': 481, 'movieId': 949, 'rating': 4.3, 'timestamp': 1746017571}
# 5003
# {'userId': 75, 'movieId': 566, 'rating': 4.8, 'timestamp': 1746017575}
# 5004
# {'userId': 500, 'movieId': 776, 'rating': 4.6, 'timestamp': 1746017577}
# 5005
# {'userId': 507, 'movieId': 640, 'rating': 2.0, 'timestamp': 1746017580}
# 5006
# {'userId': 36, 'movieId': 88, 'rating': 4.7, 'timestamp': 1746017582}
# 5007
# {'userId': 522, 'movieId': 25, 'rating': 0.6, 'timestamp': 1746017585}
# 5008
# {'userId': 183, 'movieId': 437, 'rating': 4.0, 'timestamp': 1746017587}
# 5009
# {'userId': 364, 'movieId': 743, 'rating': 1.9, 'timestamp': 1746017592}
# 5010
# {'userId': 466, 'movieId': 637, 'rating': 1.4, 'timestamp': 1746017596}
# 5011
# {'userId': 654, 'movieId': 104, 'rating': 1.4, 'timestamp': 1746017600}
# 5012
# {'userId': 410, 'movieId': 470, 'rating': 4.8, 'timestamp': 1746017605}
# 5013
# {'userId': 467, 'movieId': 358, 'rating': 4.4, 'timestamp': 1746017608}
# 5014
# {'userId': 963, 'movieId': 513, 'rating': 2.4, 'timestamp': 1746017613}
# 5015
# {'userId': 445, 'movieId': 729, 'rating': 0.7, 'timestamp': 1746017617}
# 5016
# {'userId': 89, 'movieId': 325, 'rating': 5.0, 'timestamp': 1746017621}
# 5017
# {'userId': 376, 'movieId': 212, 'rating': 1.6, 'timestamp': 1746017624}
# 5018
# {'userId': 897, 'movieId': 944, 'rating': 2.7, 'timestamp': 1746017627}
# 5019
# {'userId': 468, 'movieId': 589, 'rating': 2.6, 'timestamp': 1746017630}
# 5020
# {'userId': 344, 'movieId': 508, 'rating': 3.2, 'timestamp': 1746017635}
# 5021
# {'userId': 746, 'movieId': 879, 'rating': 0.9, 'timestamp': 1746017639}
# 5022
# {'userId': 997, 'movieId': 969, 'rating': 4.0, 'timestamp': 1746017644}
# 5023
# {'userId': 426, 'movieId': 15, 'rating': 4.8, 'timestamp': 1746017647}
# 5024
# {'userId': 330, 'movieId': 342, 'rating': 1.6, 'timestamp': 1746017650}
# 5025
# {'userId': 211, 'movieId': 158, 'rating': 1.9, 'timestamp': 1746017653}
# 5026
# {'userId': 707, 'movieId': 560, 'rating': 0.6, 'timestamp': 1746017655}
# 5027
# {'userId': 102, 'movieId': 932, 'rating': 4.3, 'timestamp': 1746017658}
# 5028
# {'userId': 208, 'movieId': 556, 'rating': 3.6, 'timestamp': 1746017662}
# 5029
# {'userId': 293, 'movieId': 262, 'rating': 0.7, 'timestamp': 1746017666}
# 5030
# {'userId': 301, 'movieId': 736, 'rating': 4.2, 'timestamp': 1746017668}
# 5031
# {'userId': 333, 'movieId': 368, 'rating': 2.0, 'timestamp': 1746017673}
# 5032
# {'userId': 237, 'movieId': 727, 'rating': 2.8, 'timestamp': 1746017677}
# 5033
# {'userId': 434, 'movieId': 539, 'rating': 4.3, 'timestamp': 1746017681}
# 5034
# {'userId': 627, 'movieId': 81, 'rating': 4.7, 'timestamp': 1746017685}
# 5035
# {'userId': 603, 'movieId': 669, 'rating': 2.8, 'timestamp': 1746017689}
# 5036
# {'userId': 393, 'movieId': 471, 'rating': 1.1, 'timestamp': 1746017693}
# 5037
# {'userId': 414, 'movieId': 828, 'rating': 1.4, 'timestamp': 1746017697}
# 5038
# {'userId': 86, 'movieId': 675, 'rating': 0.5, 'timestamp': 1746017699}
# 5039
# {'userId': 758, 'movieId': 279, 'rating': 0.9, 'timestamp': 1746017703}
# 5040
# {'userId': 250, 'movieId': 280, 'rating': 4.2, 'timestamp': 1746017707}
# 5041
# {'userId': 310, 'movieId': 387, 'rating': 3.0, 'timestamp': 1746017711}
# 5042
# {'userId': 154, 'movieId': 119, 'rating': 2.5, 'timestamp': 1746017716}
# 5043
# {'userId': 351, 'movieId': 282, 'rating': 4.6, 'timestamp': 1746017720}
# 5044
# {'userId': 998, 'movieId': 839, 'rating': 1.3, 'timestamp': 1746017724}
# 5045
# {'userId': 560, 'movieId': 571, 'rating': 2.6, 'timestamp': 1746017726}
# 5046
# {'userId': 27, 'movieId': 712, 'rating': 3.0, 'timestamp': 1746017729}
# 5047
# {'userId': 438, 'movieId': 827, 'rating': 1.9, 'timestamp': 1746017733}
# 5048
# {'userId': 189, 'movieId': 612, 'rating': 1.4, 'timestamp': 1746017737}
# 5049
# {'userId': 668, 'movieId': 556, 'rating': 4.9, 'timestamp': 1746017740}
# 5050
# {'userId': 418, 'movieId': 163, 'rating': 1.3, 'timestamp': 1746017744}
# 5051
# {'userId': 653, 'movieId': 896, 'rating': 3.3, 'timestamp': 1746017746}
# 5052
# {'userId': 868, 'movieId': 395, 'rating': 2.5, 'timestamp': 1746017750}
# 5053
# {'userId': 152, 'movieId': 93, 'rating': 4.8, 'timestamp': 1746017755}
# 5054
# {'userId': 754, 'movieId': 617, 'rating': 1.9, 'timestamp': 1746017759}
# 5055
# {'userId': 604, 'movieId': 112, 'rating': 1.4, 'timestamp': 1746017762}
# 5056
# {'userId': 670, 'movieId': 773, 'rating': 2.1, 'timestamp': 1746017765}
# 5057
# {'userId': 833, 'movieId': 876, 'rating': 1.4, 'timestamp': 1746017769}
# 5058
# {'userId': 680, 'movieId': 56, 'rating': 4.3, 'timestamp': 1746017773}
# 5059
# {'userId': 560, 'movieId': 112, 'rating': 4.9, 'timestamp': 1746017778}
# 5060
# {'userId': 837, 'movieId': 569, 'rating': 2.8, 'timestamp': 1746017781}
# 5061
# {'userId': 556, 'movieId': 442, 'rating': 1.2, 'timestamp': 1746017784}
# 5062
# {'userId': 716, 'movieId': 2, 'rating': 3.7, 'timestamp': 1746017788}
# 5063
# {'userId': 749, 'movieId': 172, 'rating': 2.2, 'timestamp': 1746017790}
# 5064
# {'userId': 808, 'movieId': 669, 'rating': 3.6, 'timestamp': 1746017794}
# 5065
# {'userId': 677, 'movieId': 337, 'rating': 2.8, 'timestamp': 1746017796}
# 5066
# {'userId': 190, 'movieId': 691, 'rating': 1.8, 'timestamp': 1746017800}
# 5067
# {'userId': 590, 'movieId': 51, 'rating': 2.6, 'timestamp': 1746017803}
# 5068
# {'userId': 423, 'movieId': 230, 'rating': 2.9, 'timestamp': 1746017807}
# 5069
# {'userId': 910, 'movieId': 545, 'rating': 4.5, 'timestamp': 1746017810}
# 5070
# {'userId': 303, 'movieId': 688, 'rating': 1.1, 'timestamp': 1746017814}
# 5071
# {'userId': 351, 'movieId': 444, 'rating': 2.6, 'timestamp': 1746017818}
# 5072
# {'userId': 181, 'movieId': 569, 'rating': 3.6, 'timestamp': 1746017823}
# 5073
# {'userId': 897, 'movieId': 911, 'rating': 1.5, 'timestamp': 1746017825}
# 5074
# {'userId': 848, 'movieId': 891, 'rating': 1.0, 'timestamp': 1746017829}
# 5075
# {'userId': 498, 'movieId': 484, 'rating': 2.3, 'timestamp': 1746017833}
# 5076
# {'userId': 190, 'movieId': 402, 'rating': 4.3, 'timestamp': 1746017836}
# 5077
# {'userId': 458, 'movieId': 226, 'rating': 2.2, 'timestamp': 1746017839}
# 5078
# {'userId': 568, 'movieId': 451, 'rating': 4.7, 'timestamp': 1746017842}
# 5079
# {'userId': 791, 'movieId': 592, 'rating': 3.7, 'timestamp': 1746017845}
# 5080
# {'userId': 468, 'movieId': 259, 'rating': 3.9, 'timestamp': 1746017849}
# 5081
# {'userId': 342, 'movieId': 401, 'rating': 0.7, 'timestamp': 1746017853}
# 5082
# {'userId': 186, 'movieId': 970, 'rating': 0.9, 'timestamp': 1746017857}
# 5083
# {'userId': 116, 'movieId': 997, 'rating': 2.1, 'timestamp': 1746017862}
# 5084
# {'userId': 496, 'movieId': 166, 'rating': 1.0, 'timestamp': 1746017866}
# 5085
# {'userId': 257, 'movieId': 413, 'rating': 2.4, 'timestamp': 1746017869}
# 5086
# {'userId': 132, 'movieId': 24, 'rating': 3.2, 'timestamp': 1746017872}
# 5087
# {'userId': 257, 'movieId': 936, 'rating': 3.6, 'timestamp': 1746017875}
# 5088
# {'userId': 276, 'movieId': 306, 'rating': 3.4, 'timestamp': 1746017879}
# 5089
# {'userId': 747, 'movieId': 83, 'rating': 4.2, 'timestamp': 1746017883}
# 5090
# {'userId': 140, 'movieId': 676, 'rating': 3.6, 'timestamp': 1746017887}
# 5091
# {'userId': 892, 'movieId': 995, 'rating': 0.9, 'timestamp': 1746017892}
# 5092
# {'userId': 297, 'movieId': 294, 'rating': 1.9, 'timestamp': 1746017895}
# 5093
# {'userId': 882, 'movieId': 779, 'rating': 1.8, 'timestamp': 1746017900}
# 5094
# {'userId': 601, 'movieId': 953, 'rating': 3.7, 'timestamp': 1746017903}
# 5095
# {'userId': 327, 'movieId': 437, 'rating': 4.5, 'timestamp': 1746017908}
# 5096
# {'userId': 314, 'movieId': 429, 'rating': 2.2, 'timestamp': 1746017911}
# 5097
# {'userId': 942, 'movieId': 111, 'rating': 2.2, 'timestamp': 1746017914}
# 5098
# {'userId': 497, 'movieId': 797, 'rating': 4.9, 'timestamp': 1746017917}
# 5099
# {'userId': 757, 'movieId': 453, 'rating': 0.9, 'timestamp': 1746017921}
# 5100
# {'userId': 660, 'movieId': 567, 'rating': 4.3, 'timestamp': 1746017925}
# 5101
# {'userId': 217, 'movieId': 122, 'rating': 3.0, 'timestamp': 1746017929}
# 5102
# {'userId': 34, 'movieId': 982, 'rating': 4.5, 'timestamp': 1746017933}
# 5103
# {'userId': 770, 'movieId': 591, 'rating': 2.2, 'timestamp': 1746017936}
# 5104
# {'userId': 869, 'movieId': 164, 'rating': 3.2, 'timestamp': 1746017939}
# 5105
# {'userId': 169, 'movieId': 613, 'rating': 3.2, 'timestamp': 1746017944}
# 5106
# {'userId': 36, 'movieId': 0, 'rating': 4.4, 'timestamp': 1746017948}
# 5107
# {'userId': 524, 'movieId': 624, 'rating': 1.3, 'timestamp': 1746017950}
# 5108
# {'userId': 934, 'movieId': 155, 'rating': 2.7, 'timestamp': 1746017955}
# 5109
# {'userId': 132, 'movieId': 205, 'rating': 0.8, 'timestamp': 1746017959}
# 5110
# {'userId': 682, 'movieId': 451, 'rating': 1.6, 'timestamp': 1746017961}
# 5111
# {'userId': 711, 'movieId': 941, 'rating': 2.4, 'timestamp': 1746017964}
# 5112
# {'userId': 615, 'movieId': 653, 'rating': 3.8, 'timestamp': 1746017967}
# 5113
# {'userId': 119, 'movieId': 826, 'rating': 3.9, 'timestamp': 1746017971}
# 5114
# {'userId': 736, 'movieId': 663, 'rating': 2.7, 'timestamp': 1746017974}
# 5115
# {'userId': 817, 'movieId': 493, 'rating': 3.6, 'timestamp': 1746017976}
# 5116
# {'userId': 609, 'movieId': 79, 'rating': 2.7, 'timestamp': 1746017981}
# 5117
# {'userId': 695, 'movieId': 754, 'rating': 3.5, 'timestamp': 1746017984}
# 5118
# {'userId': 11, 'movieId': 964, 'rating': 0.7, 'timestamp': 1746017988}
# 5119
# {'userId': 992, 'movieId': 316, 'rating': 1.8, 'timestamp': 1746017991}
# 5120
# {'userId': 949, 'movieId': 890, 'rating': 2.9, 'timestamp': 1746017993}
# 5121
# {'userId': 89, 'movieId': 86, 'rating': 2.4, 'timestamp': 1746017998}
# 5122
# {'userId': 440, 'movieId': 655, 'rating': 3.4, 'timestamp': 1746018002}
# 5123
# {'userId': 828, 'movieId': 331, 'rating': 2.9, 'timestamp': 1746018007}
# 5124
# {'userId': 799, 'movieId': 281, 'rating': 3.3, 'timestamp': 1746018010}
# 5125
# {'userId': 530, 'movieId': 577, 'rating': 2.0, 'timestamp': 1746018014}
# 5126
# {'userId': 940, 'movieId': 518, 'rating': 3.8, 'timestamp': 1746018017}
# 5127
# {'userId': 306, 'movieId': 392, 'rating': 4.8, 'timestamp': 1746018019}
# 5128
# {'userId': 417, 'movieId': 902, 'rating': 2.9, 'timestamp': 1746018022}
# 5129
# {'userId': 171, 'movieId': 310, 'rating': 2.9, 'timestamp': 1746018026}
# 5130
# {'userId': 52, 'movieId': 57, 'rating': 2.9, 'timestamp': 1746018029}
# 5131
# {'userId': 75, 'movieId': 806, 'rating': 4.5, 'timestamp': 1746018034}
# 5132
# {'userId': 249, 'movieId': 142, 'rating': 2.8, 'timestamp': 1746018037}
# 5133
# {'userId': 785, 'movieId': 474, 'rating': 1.5, 'timestamp': 1746018041}
# 5134
# {'userId': 660, 'movieId': 244, 'rating': 3.2, 'timestamp': 1746018044}
# 5135
# {'userId': 434, 'movieId': 769, 'rating': 4.4, 'timestamp': 1746018046}
# 5136
# {'userId': 537, 'movieId': 779, 'rating': 4.8, 'timestamp': 1746018049}
# 5137
# {'userId': 30, 'movieId': 815, 'rating': 3.8, 'timestamp': 1746018053}
# 5138
# {'userId': 244, 'movieId': 643, 'rating': 0.8, 'timestamp': 1746018056}
